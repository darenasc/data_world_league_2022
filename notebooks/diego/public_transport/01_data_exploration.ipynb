# %%
import pandas as pd
from pandas_profiling import ProfileReport
from pathlib import Path

# %%
output_folder = Path("../../../output/diego/cascais")
cascais_path = Path("data/cascais/")

# %%
dfs = {}
# Generating exploratory analysis for the input data
for item in cascais_path.glob('*.txt'):
    df = pd.read_csv(item, sep=',')
    df.name = item.stem
    profile = ProfileReport(df, title=f"{item.stem}")
    profile.to_file(output_folder / f"{item.stem}.html")
    dfs[item.stem] = df

# %% [markdown]
# - `stop_times` is a relevant dataset.
# - `trips` has a `shape_id` column that joins with the `shapes` file.
# - `stops` contains the coodinates of the bus stops.

# %%
dfs.keys()
# Out:
# dict_keys(['fare_attributes', 'agency', 'calendar_dates', 'stop_times', 'shapes', 'trips', 'feed_info', 'stops', 'calendar', 'routes'])

# %%
n = 'stop_times'
dfs[n]
# Out:
#                                       trip_id arrival_time departure_time  \
# 0         M01-1-001-A-U-09h15-ParedeTerminalR     09:15:00       09:15:00
# 1         M01-1-001-A-U-09h15-ParedeTerminalR     09:17:00       09:17:00
# 2         M01-1-001-A-U-09h15-ParedeTerminalR     09:18:00       09:18:00
# 3         M01-1-001-A-U-09h15-ParedeTerminalR     09:20:00       09:20:00
# 4         M01-1-001-A-U-09h15-ParedeTerminalR     09:21:30       09:21:30
# ...                                       ...          ...            ...
# 111763  M29-2-086-A-SDF-24h45-CascaiShoppingT     24:51:00       24:51:00
# 111764  M29-2-086-A-SDF-24h45-CascaiShoppingT     24:52:42       24:52:42
# 111765  M29-2-086-A-SDF-24h45-CascaiShoppingT     24:53:48       24:53:48
# 111766  M29-2-086-A-SDF-24h45-CascaiShoppingT     24:54:38       24:54:38
# 111767  M29-2-086-A-SDF-24h45-CascaiShoppingT     24:56:00       24:56:00
#
#         stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# ...

# %%
for df_ in dfs:
    profile = ProfileReport(df_, title=f"{df_.name}")
    profile.to_file(f"{df_.name}.html")
